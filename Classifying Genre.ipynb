# %%
import pandas as pd

tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')
track=tracks[['track_id','genre_top']]


echonest_metrics = pd.read_json('datasets/echonest-metrics.json', precise_float=True)


echo_tracks = echonest_metrics.merge(track, on='track_id')

echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col1,#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col2,#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col3,#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col4,#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col5,#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col6,#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col7,#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col1,#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col3,#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col5,#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col7,#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col2,#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col6,#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col8,#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col2{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col3{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col4{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col5{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col6,#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col3{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col7,#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col7{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row0_col8,#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col6{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col2{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col4,#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col1{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col5,#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col4{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col6,#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col1{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row1_col8{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col3{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col1,#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col1{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col3{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col6{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row2_col8{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col0,#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col3{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col1{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col2,#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col2{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col4{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col5,#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col7{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col7{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row3_col8,#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col7{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col0{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col3{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row4_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col1{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col2{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col4,#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col7{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col6{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row5_col8{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col2{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col3,#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col5{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row6_col8{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col4{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col5{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col6{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row7_col8{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col0{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col1{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col2{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col4{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col5{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col6{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_a2b644c6_e866_11eb_b520_a497b16350a0row8_col7{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }</style><table id="T_a2b644c6_e866_11eb_b520_a497b16350a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >track_id</th>        <th class="col_heading level0 col

# %%
 
features = echo_tracks.drop(['genre_top','track_id'], axis=1)

labels = echo_tracks['genre_top']

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_
print(pca.n_components_)


fig, ax = plt.subplots()
ax.bar(exp_variance,range(8))
ax.set_xlabel('Principal Component #')
# Out:
# 8
# Text(0.5, 0, 'Principal Component #')

# %%
# Import numpy
import numpy as np
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig, ax = plt.subplots()
ax.plot()
ax.axhline(y=0.85, linestyle='-')

# choose the n_components where about 85% of our variance can be explained
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)
